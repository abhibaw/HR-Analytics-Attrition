# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
df = pd.read_csv("../data/raw/HR-Employee-Attrition.csv")

# %%
engine = create_engine(
    "mysql+pymysql://root:Abhipushp%402002@localhost/hr_analytics"
)

df.to_sql(
    "employees",
    engine,
    if_exists="replace",
    index=False
)

print("Loaded", len(df), "rows")
# Out:
# Loaded 1470 rows
